# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
np.random.seed(10)

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['saint-dizier',
#  'albany',
#  'eldorado',
#  'aurillac',
#  'biak',
#  'cape town',
#  'bluff',
#  'balykshi',
#  'mataura',
#  'punta arenas',
#  'turayf',
#  'barentsburg',
#  'puerto ayora',
#  'chunskiy',
#  'loikaw',
#  'vila franca do campo',
#  'mahebourg',
#  'bilibino',
#  'yinchuan',
#  'atuona',
#  'farafangana',
#  'kapaa',
#  'xique-xique',
#  'asau',
#  'hirara',
#  'saleaula',
#  'kingsville',
#  'salalah',
#  'bethel',
#  'goderich',
#  'ostrovnoy',
#  'richards bay',
#  'hobart',
#  'saldanha',
#  'iqaluit',
#  'ushuaia',
#  'cabo san lucas',
#  'provideniya',
#  'mirnyy',
#  'alofi',
#  'zhanatas',
#  'kiama',
#  'saskylakh',
#  'maun',
#  'hermanus',
#  'attawapiskat',
#  'iquique',
#  'chokurdakh',
#  'upernavik',
#  'tocache',
#  'karla',
#  'jamestown',
#  'marawi',
#  'illoqqortoormiut',
#  'eyl',
#  'new norfolk',
#  'ampanihy',
#  'lebu',
#  'oranjemund',
#  'stephenville',
#  'laguna',
#  'el balyana',
#  'vao',
#  'kharp',
#  'valentigney',
#  'yellowknife',
#  'lompoc',
#  'taolanaro',
#  'santa rosa',
#  'busselton',
#  'airai',
#  'mergui',
#  'ambon',
#  'bambous virieux',
#  'matara',
#  'khatanga',
#  'bengkulu',
#  'scottsburgh',
#  'olafsvik',
#  'citeureup',
#  'nanortalik',
#  'isfana',
#  'umm durman',
#  'geraldton',
#  'flinders',
#  'ixtapa',
#  'palestine',
#  'mar del plata',
#  'kaeo',
#  'bredasdorp',
#  'tuatapere',
#  'clyde river',
#  'torbay',
#  'port alfred',
#  'redmond',
#  'amahai',
#  'rikitea',
#  'los llanos de aridane',
#  'bandarbeyla',
#  'castro',
#  'guaranesia',
#  'balud',
#  'hilo',
#  'kracheh',
#  'mora',
#  'nome',
#  'moussoro',
#  'sentyabrskiy',
#  'nador',
#  'vaitupu',
#  'kijang',
#  'tigil',
#  'cootehill',
#  'mangrol',
#  'georgetown',
#  'komsomolskiy',
#  'vizinga',
#  'butaritari',
#  'moron',
#  'san patricio',
#  'prince rupert',
#  'darhan',
#  'hithadhoo',
#  'buala',
#  'kysyl-syr',
#  'zhengjiatun',
#  'carnarvon',
#  'bafoulabe',
#  'luderitz',
#  'grand centre',
#  'port hardy',
#  'pisco',
#  'pavino',
#  'jackson',
#  'afgoye',
#  'cidreira',
#  'talnakh',
#  'qaanaaq',
#  'wellington',
#  'thompson',
#  'ahipara',
#  'lavrentiya',
#  'sao felix do xingu',
#  'ola',
#  'warrnambool',
#  'khalkhal',
#  'kodiak',
#  'anadyr',
#  'sabang',
#  'kavieng',
#  'kruisfontein',
#  'sept-iles',
#  'hualmay',
#  'atka',
#  'port blair',
#  'yenangyaung',
#  'saint-augustin',
#  'batemans bay',
#  'vaini',
#  'dikson',
#  'dunda',
#  'nobeoka',
#  'tarko-sale',
#  'tasiilaq',
#  'belushya guba',
#  'ponta do sol',
#  'constitucion',
#  'babu',
#  'kamenka',
#  'morondava',
#  'karratha',
#  'mogoytuy',
#  'guerrero negro',
#  'klaksvik',
#  'abha',
#  'port elizabeth',
#  'rio grande',
#  'pagman',
#  'dawson creek',
#  'mersing',
#  'fortuna',
#  'saint-philippe',
#  'tateyama',
#  'solton',
#  'tumannyy',
#  'praia',
#  'kamaishi',
#  'te anau',
#  'impfondo',
#  'lolua',
#  'teknaf',
#  'nikolskoye',
#  'verkhnevilyuysk',
#  'bathsheba',
#  'veraval',
#  'college',
#  'gat',
#  'kisangani',
#  'luganville',
#  'la rioja',
#  'kahului',
#  'mys shmidta',
#  'bollnas',
#  'avarua',
#  'kushiro',
#  'grand river south east',
#  'sault sainte marie',
#  'san andres',
#  'bur gabo',
#  'rach gia',
#  'olinda',
#  'praia da vitoria',
#  'ushtobe',
#  'surt',
#  'pangkalanbuun',
#  'basco',
#  'sulmona',
#  'margate',
#  'ancud',
#  'east london',
#  'haines junction',
#  'souillac',
#  'caborca',
#  'zhaocheng',
#  'nadym',
#  'hambantota',
#  'faanui',
#  'san juan de los morros',
#  'jaisalmer',
#  'bonavista',
#  'srednekolymsk',
#  'eganville',
#  'paracuru',
#  'cochrane',
#  'maceio',
#  'mokhsogollokh',
#  'maposeni',
#  'healesville',
#  'morgan city',
#  'san cristobal',
#  'yazykovo',
#  'severo-kurilsk',
#  'samusu',
#  'houston',
#  'esna',
#  'angra dos reis',
#  'hat yai',
#  'missoula',
#  'tvoroyri',
#  'kudahuvadhoo',
#  'balotra',
#  'tuktoyaktuk',
#  'klyuchi',
#  'caravelas',
#  'nizhniy tsasuchey',
#  'sandnessjoen',
#  'havre-saint-pierre',
#  'tiksi',
#  'zelenoborsk',
#  'fallon',
#  'mercedes',
#  'dunedin',
#  'faya',
#  'barrow',
#  'luoyang',
#  'ouargaye',
#  'aginskoye',
#  'alpatovo',
#  'samarai',
#  'sandwick',
#  'kieta',
#  'samalaeulu',
#  'aksarka',
#  'labuhan',
#  'novobelokatay',
#  'uk',
#  'kaitangata',
#  'urengoy',
#  'neiafu',
#  'nyagan',
#  'cheuskiny',
#  'egvekinot',
#  'jurado',
#  'freeport',
#  'kashan',
#  'port lincoln',
#  'cayenne',
#  'dolores',
#  'altud',
#  'cherskiy',
#  'bikaner',
#  'calbe',
#  'coquimbo',
#  'bud',
#  'mount gambier',
#  'tsiroanomandidy',
#  'jiayuguan',
#  'sanming',
#  'plettenberg bay',
#  'miraflores',
#  'matamoros',
#  'praya',
#  'san julian',
#  'torrijos',
#  'tartagal',
#  'kavaratti',
#  'esperance',
#  'tsihombe',
#  'chapais',
#  'hasaki',
#  'longyearbyen',
#  'payson',
#  'tangjiazhuang',
#  'ossora',
#  'ndele',
#  'arraial do cabo',
#  'codrington',
#  'grindavik',
#  'catamarca',
#  'amderma',
#  'nagayo',
#  'el campo',
#  'muros',
#  'fairbanks',
#  'ovalle',
#  'khani',
#  'tiarei',
#  'nizhneyansk',
#  'mount isa',
#  'bijie',
#  'chumikan',
#  'the pas',
#  'bowmore',
#  'lagoa',
#  'pangody',
#  'alta gracia',
#  'chuy',
#  'isla vista',
#  'salinopolis',
#  'saint george',
#  'la ronge',
#  'garachine',
#  'satitoa',
#  'berlevag',
#  'namikupa',
#  'barra patuca',
#  'nagato',
#  'galveston',
#  'mandalgovi',
#  'akyab',
#  'kibray',
#  'naze',
#  'hamilton',
#  'bontang',
#  'lamar',
#  'contamana',
#  'yaqui',
#  'moroni',
#  'shelburne',
#  'matameye',
#  'karlshamn',
#  'portobelo',
#  'rio gallegos',
#  'xining',
#  'henties bay',
#  'ust-koksa',
#  'meulaboh',
#  'banda aceh',
#  'mier',
#  'sao joao da barra',
#  'vrbove',
#  'tilichiki',
#  'hondo',
#  'chom bung',
#  'nantucket',
#  'trinidad',
#  'myitkyina',
#  'sioux lookout',
#  'quelimane',
#  'san quintin',
#  'leningradskiy',
#  'arlit',
#  'borba',
#  'vardo',
#  'mitsamiouli',
#  'ribeira grande',
#  'rengo',
#  'lagos',
#  'codajas',
#  'manadhoo',
#  'husavik',
#  'nanakuli',
#  'patnos',
#  'novoagansk',
#  'montepuez',
#  'vestmannaeyjar',
#  'rawson',
#  'ilulissat',
#  'urlati',
#  'melfi',
#  'evensk',
#  'ulaanbaatar',
#  'comodoro rivadavia',
#  'deleni',
#  'lindi',
#  'yar-sale',
#  'palana',
#  'coihaique',
#  'rutana',
#  'omboue',
#  'aberdeen',
#  'alta floresta',
#  'loandjili',
#  'termoli',
#  'washington',
#  'nara',
#  'tocopilla',
#  'burley',
#  'adamovka',
#  'kampene',
#  'alice springs',
#  'sibolga',
#  'sorland',
#  'karacakoy',
#  'fort nelson',
#  'yumen',
#  'katsuura',
#  'karakendzha',
#  'vidim',
#  'roma',
#  'phalaborwa',
#  'abiramam',
#  'vega de alatorre',
#  'sitrah',
#  'shimoda',
#  'lata',
#  'namibe',
#  'north bend',
#  'lewistown',
#  'pacific grove',
#  'lodja',
#  'damietta',
#  'rayong',
#  'pevek',
#  'palabuhanratu',
#  'touros',
#  'yabrud',
#  'yulara',
#  'abu samrah',
#  'sao lourenco da serra',
#  'adre',
#  'koutiala',
#  'kizukuri',
#  'makrana',
#  'port moresby',
#  'kimbe',
#  'kidal',
#  'balao',
#  'victoria',
#  'pouembout',
#  'brigantine',
#  'belyy yar',
#  'padang',
#  'boda',
#  'caxias',
#  'bolungarvik',
#  'deer lake',
#  'colwyn bay',
#  'cairns',
#  'shangrao',
#  'baykit',
#  'port shepstone',
#  'kemijarvi',
#  'hobyo',
#  'petropavlovsk-kamchatskiy',
#  'tasgaon',
#  'deputatskiy',
#  'blythe',
#  'maniitsoq',
#  'linxia',
#  'nancha',
#  'tonkino',
#  'shaunavon',
#  'harnosand',
#  'cap malheureux',
#  'ostersund',
#  'mechanicsville',
#  'daru',
#  'bajram curri',
#  'guaimaca',
#  'surman',
#  'kasongo',
#  'charters towers',
#  'norrtalje',
#  'sapulpa',
#  'puerto el triunfo',
#  'kyshtovka',
#  'ewo',
#  'kangaatsiaq',
#  'flin flon',
#  'karkaralinsk',
#  'victor harbor',
#  'neuquen',
#  'norilsk',
#  'perbaungan',
#  'bronnoysund',
#  'svetlogorsk',
#  'winnemucca',
#  'mandi bahauddin',
#  'ribeira brava',
#  'kannad',
#  'huinan',
#  'norman wells',
#  'nagua',
#  'malazgirt',
#  'trelew',
#  'la union',
#  'narsaq',
#  'sajanan',
#  'pinega',
#  'boca do acre',
#  'las margaritas',
#  'ous',
#  'itarema',
#  'srivardhan',
#  'riberalta',
#  'lillooet',
#  'krasnoselkup',
#  'nizwa',
#  'halalo',
#  'honiara',
#  'buta',
#  'qasigiannguit',
#  'duncan',
#  'paonta sahib',
#  'mitu',
#  'kiunga',
#  'valdemarpils',
#  'rocha',
#  'cape coast',
#  'salinas',
#  'that phanom',
#  'invermere',
#  'sur',
#  'isangel',
#  'babanusah',
#  'san jose',
#  'kenai',
#  'zhigansk',
#  'chardara',
#  'dingle',
#  'grand gaube',
#  'jasper',
#  'itupiranga',
#  'xinzhi',
#  'vestmanna',
#  'andenes',
#  'sohag',
#  'necochea',
#  'umm lajj',
#  'khomeyn',
#  'pestretsy',
#  'kelowna',
#  'ust-omchug',
#  'cascais',
#  'sungaipenuh',
#  'moerai',
#  'tessalit',
#  'pilikwe',
#  'general cepeda',
#  'lashio',
#  'nelson bay',
#  'sao filipe',
#  'of',
#  'hofn',
#  'kailua',
#  'jumla',
#  'kuching',
#  'harnai',
#  'tongchuan',
#  'makakilo city',
#  'yuyao',
#  'manta',
#  'aripuana',
#  'casambalangan',
#  'burkhala']

# %%
url = " http://api.openweathermap.org/data/2.5/weather?q="
lat=[]
lng=[]

#print("Beginning Data Retrieval")
#api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
#for city in cities:
    
    #try:
        #response = requests.get(url +city + '&appid='+weather_api_key ).json()
        #print(city)
        #print(response['coord'])
        #lat.append(response['coord']['lat'])
    #except KeyError:
        #print(city + "Not Found")
        
#print(lat)
response = requests.get(url +'blythe' '&appid='+weather_api_key).json()
#city = response.json()
print(response)
# Out:
# Beginning Data Retrieval
# saint-dizier
# {'lon': 5.08, 'lat': 48.42}
# albany
# {'lon': -73.97, 'lat': 42.6}
# eldorado
# {'lon': -54.28, 'lat': -23.79}
# aurillac
# {'lon': 2.45, 'lat': 44.92}
# biak
# {'lon': 122.88, 'lat': -0.91}
# cape town
# {'lon': 18.42, 'lat': -33.93}
# bluff
# {'lon': 168.33, 'lat': -46.6}
# balykshi
# {'lon': 51.87, 'lat': 47.07}
# mataura
# {'lon': 168.86, 'lat': -46.19}
# punta arenas
# {'lon': -70.92, 'lat': -53.15}
# turayf
# {'lon': 38.66, 'lat': 31.67}
# barentsburg
# barentsburgNot Found
# puerto ayora
# {'lon': -90.35, 'lat': -0.74}
# chunskiy
# {'lon': 99.63, 'lat': 56.08}
# loikaw
# {'lon': 97.21, 'lat': 19.67}
# vila franca do campo
# {'lon': -25.43, 'lat': 37.72}
# mahebourg
# {'lon': 57.7, 'lat': -20.41}
# bilibino
# {'lon': 166.44, 'lat': 68.05}
# yinchuan
# {'lon': 106.27, 'lat': 38.47}
# atuona
# {'lon': -139.03, 'lat': -9.8}
# farafangana
# {'lon': 47.83, 'lat': -22.82}
# kapaa
# {'lon': -159.32, 'lat': 22.08}
# xique-xique
# {'lon': -42.73, 'lat': -10.82}
# asau
# {'lon': 26.4, 'lat': 46.43}
# hirara
# {'lon': 125.28, 'lat': 24.8}
# saleaula
# saleaulaNot Found
# kingsville
# {'lon': -97.86, 'lat': 27.52}
# salalah
# {'lon': 54.09, 'lat': 17.02}
# bethel
# {'lon': -73.41, 'lat': 41.37}
# goderich
# {'lon': -81.72, 'lat': 43.75}
# ostrovnoy
# {'lon': 39.51, 'lat': 68.05}
# richards bay
# {'lon': 32.04, 'lat': -28.78}
# hobart
# {'lon': 147.33, 'lat': -42.88}
# saldanha
# {'lon': 17.94, 'lat': -33.01}
# iqaluit
# {'lon': -68.51, 'lat': 63.75}
# ushuaia
# {'lon': -68.3, 'lat': -54.8}
# cabo san lucas
# {'lon': -109.91, 'lat': 22.89}
# provideniya
# {'lon': -173.3, 'lat': 64.38}
# mirnyy
# {'lon': 113.96, 'lat': 62.54}
# alofi
# {'lon': -169.92, 'lat': -19.06}
# zhanatas
# zhanatasNot Found
# kiama
# {'lon': 150.87, 'lat': -34.68}
# saskylakh
# {'lon': 114.08, 'lat': 71.92}
# maun
# {'lon': 23.42, 'lat': -19.98}
# hermanus
# {'lon': 19.23, 'lat': -34.42}
# attawapiskat
# attawapiskatNot Found
# iquique
# {'lon': -70.14, 'lat': -20.22}
# chokurdakh
# {'lon': 147.92, 'lat': 70.63}
# upernavik
# {'lon': -56.15, 'lat': 72.79}
# tocache
# {'lon': -76.51, 'lat': -8.18}
# karla
# {'lon': 24.93, 'lat': 59.37}
# jamestown
# {'lon': -79.24, 'lat': 42.1}
# marawi
# {'lon': 124.29, 'lat': 8}
# illoqqortoormiut
# illoqqortoormiutNot Found
# eyl
# {'lon': 49.82, 'lat': 7.98}
# new norfolk
# {'lon': 147.06, 'lat': -42.78}
# ampanihy
# {'lon': 44.75, 'lat': -24.7}
# lebu
# {'lon': -73.65, 'lat': -37.62}
# oranjemund
# {'lon': 16.43, 'lat': -28.55}
# stephenville
# {'lon': -98.2, 'lat': 32.22}
# laguna
# {'lon': -121.42, 'lat': 38.42}
# el balyana
# el balyanaNot Found
# vao
# {'lon': 167.48, 'lat': -22.67}
# kharp
# {'lon': 65.81, 'lat': 66.8}
# valentigney
# {'lon': 6.83, 'lat': 47.46}
# yellowknife
# {'lon': -114.35, 'lat': 62.46}
# lompoc
# {'lon': -120.46, 'lat': 34.64}
# taolanaro
# taolanaroNot Found
# santa rosa
# {'lon': 121.11, 'lat': 14.31}
# busselton
# {'lon': 115.33, 'lat': -33.65}
# airai
# {'lon': 125.41, 'lat': -8.93}
# mergui
# merguiNot Found
# ambon
# {'lon': 128.18, 'lat': -3.7}
# bambous virieux
# {'lon': 57.76, 'lat': -20.34}
# matara
# {'lon': 80.54, 'lat': 5.95}
# khatanga
# {'lon': 102.5, 'lat': 71.97}
# bengkulu
# {'lon': 102.27, 'lat': -3.8}
# scottsburgh
# scottsburghNot Found
# olafsvik
# {'lon': -23.71, 'lat': 64.89}
# citeureup
# {'lon': 106.88, 'lat': -6.49}
# nanortalik
# {'lon': -45.24, 'lat': 60.14}
# isfana
# {'lon': 69.53, 'lat': 39.84}
# umm durman
# umm durmanNot Found
# geraldton
# {'lon': 114.6, 'lat': -28.77}
# flinders
# {'lon': 150.86, 'lat': -34.58}
# ixtapa
# {'lon': -105.2, 'lat': 20.7}
# palestine
# {'lon': 35.2, 'lat': 31.92}
# mar del plata
# {'lon': -57.56, 'lat': -38}
# kaeo
# {'lon': 173.78, 'lat': -35.1}
# bredasdorp
# {'lon': 20.04, 'lat': -34.53}
# tuatapere
# {'lon': 167.68, 'lat': -46.13}
# clyde river
# {'lon': -68.59, 'lat': 70.47}
# torbay
# {'lon': -52.73, 'lat': 47.67}
# port alfred
# {'lon': 26.89, 'lat': -33.59}
# redmond
# {'lon': -122.12, 'lat': 47.67}
# amahai
# {'lon': 128.92, 'lat': -3.33}
# rikitea
# {'lon': -134.97, 'lat': -23.12}
# los llanos de aridane
# {'lon': -17.92, 'lat': 28.66}
# bandarbeyla
# {'lon': 50.81, 'lat': 9.49}
# castro
# {'lon': -50.01, 'lat': -24.79}
# guaranesia
# {'lon': -46.8, 'lat': -21.3}
# balud
# {'lon': 123.7, 'lat': 10.15}
# hilo
# {'lon': -155.09, 'lat': 19.73}
# kracheh
# krachehNot Found
# mora
# {'lon': 14.14, 'lat': 11.05}
# nome
# {'lon': -165.41, 'lat': 64.5}
# moussoro
# {'lon': 16.49, 'lat': 13.64}
# sentyabrskiy
# sentyabrskiyNot Found
# nador
# {'lon': -2.93, 'lat': 35.17}
# vaitupu
# vaitupuNot Found
# kijang
# {'lon': 129.21, 'lat': 35.24}
# tigil
# {'lon': 158.67, 'lat': 57.8}
# cootehill
# {'lon': -7.08, 'lat': 54.07}
# mangrol
# {'lon': 70.12, 'lat': 21.12}
# georgetown
# {'lon': 100.34, 'lat': 5.41}
# komsomolskiy
# {'lon': 71.72, 'lat': 40.43}
# vizinga
# {'lon': 50.1, 'lat': 61.07}
# butaritari
# {'lon': 172.79, 'lat': 3.07}
# moron
# {'lon': -58.62, 'lat': -34.65}
# san patricio
# {'lon': -97.52, 'lat': 28.02}
# prince rupert
# {'lon': -130.32, 'lat': 54.32}
# darhan
# {'lon': 105.92, 'lat': 49.49}
# hithadhoo
# {'lon': 73.08, 'lat': -0.6}
# buala
# {'lon': 159.59, 'lat': -8.14}
# kysyl-syr
# {'lon': 122.76, 'lat': 63.9}
# zhengjiatun
# {'lon': 123.51, 'lat': 43.51}
# carnarvon
# {'lon': 113.63, 'lat': -24.87}
# bafoulabe
# {'lon': -10.83, 'lat': 13.81}
# luderitz
# {'lon': 15.16, 'lat': -26.65}
# grand centre
# grand centreNot Found
# port hardy
# {'lon': -127.42, 'lat': 50.7}
# pisco
# {'lon': -76.22, 'lat': -13.7}
# pavino
# {'lon': 46.14, 'lat': 59.11}
# jackson
# {'lon': -122.83, 'lat': 42.42}
# afgoye
# afgoyeNot Found
# cidreira
# {'lon': -50.21, 'lat': -30.18}
# talnakh
# {'lon': 88.4, 'lat': 69.49}
# qaanaaq
# {'lon': -69.36, 'lat': 77.48}
# wellington
# {'lon': 174.78, 'lat': -41.29}
# thompson
# {'lon': -97.86, 'lat': 55.74}
# ahipara
# {'lon': 173.17, 'lat': -35.17}
# lavrentiya
# {'lon': -171, 'lat': 65.58}
# sao felix do xingu
# {'lon': -51.99, 'lat': -6.64}
# ola
# {'lon': 151.28, 'lat': 59.58}
# warrnambool
# {'lon': 142.48, 'lat': -38.38}
# khalkhal
# {'lon': 48.53, 'lat': 37.62}
# kodiak
# {'lon': -152.41, 'lat': 57.79}
# anadyr
# {'lon': 177.48, 'lat': 64.75}
# sabang
# {'lon': 95.32, 'lat': 5.89}
# kavieng
# {'lon': 150.8, 'lat': -2.57}
# kruisfontein
# {'lon': 24.73, 'lat': -34}
# sept-iles
# {'lon': -66.38, 'lat': 50.2}
# hualmay
# {'lon': -77.61, 'lat': -11.1}
# atka
# atkaNot Found
# port blair
# {'lon': 92.75, 'lat': 11.67}
# yenangyaung
# {'lon': 94.88, 'lat': 20.47}
# saint-augustin
# {'lon': -58.65, 'lat': 51.23}
# batemans bay
# {'lon': 150.18, 'lat': -35.72}
# vaini
# {'lon': -175.2, 'lat': -21.2}
# dikson
# {'lon': 80.55, 'lat': 73.51}
# dunda
# {'lon': 34.25, 'lat': -8.12}
# nobeoka
# {'lon': 131.67, 'lat': 32.58}
# tarko-sale
# {'lon': 77.78, 'lat': 64.92}
# tasiilaq
# {'lon': -37.64, 'lat': 65.61}
# belushya guba
# belushya gubaNot Found
# ponta do sol
# {'lon': -17.1, 'lat': 32.67}
# constitucion
# {'lon': -72.42, 'lat': -35.33}
# babu
# {'lon': 111.52, 'lat': 24.42}
# kamenka
# {'lon': 42.77, 'lat': 51.32}
# morondava
# {'lon': 44.28, 'lat': -20.28}
# karratha
# {'lon': 116.85, 'lat': -20.74}
# mogoytuy
# {'lon': 114.92, 'lat': 51.28}
# guerrero negro
# {'lon': -114.06, 'lat': 27.98}
# klaksvik
# {'lon': -6.59, 'lat': 62.23}
# abha
# {'lon': 42.51, 'lat': 18.22}
# port elizabeth
# {'lon': 25.57, 'lat': -33.92}
# rio grande
# {'lon': -52.1, 'lat': -32.03}
# pagman
# pagmanNot Found
# dawson creek
# {'lon': -120.24, 'lat': 55.77}
# mersing
# {'lon': 103.84, 'lat': 2.43}
# fortuna
# {'lon': -124.16, 'lat': 40.6}
# saint-philippe
# {'lon': 55.77, 'lat': -21.36}
# tateyama
# {'lon': 139.87, 'lat': 34.98}
# solton
# {'lon': 86.48, 'lat': 52.84}
# tumannyy
# tumannyyNot Found
# praia
# {'lon': -23.51, 'lat': 14.92}
# kamaishi
# {'lon': 141.88, 'lat': 39.27}
# te anau
# {'lon': 167.72, 'lat': -45.42}
# impfondo
# {'lon': 18.07, 'lat': 1.64}
# lolua
# loluaNot Found
# teknaf
# {'lon': 92.31, 'lat': 20.86}
# nikolskoye
# {'lon': 30.79, 'lat': 59.7}
# verkhnevilyuysk
# {'lon': 120.32, 'lat': 63.45}
# bathsheba
# {'lon': -59.52, 'lat': 13.22}
# veraval
# {'lon': 70.37, 'lat': 20.9}
# college
# {'lon': -147.8, 'lat': 64.86}
# gat
# {'lon': 34.76, 'lat': 31.61}
# kisangani
# {'lon': 25.2, 'lat': 0.52}
# luganville
# {'lon': 167.17, 'lat': -15.53}
# la rioja
# {'lon': -2.5, 'lat': 42.25}
# kahului
# {'lon': -156.47, 'lat': 20.89}
# mys shmidta
# mys shmidtaNot Found
# bollnas
# {'lon': 16.39, 'lat': 61.35}
# avarua
# {'lon': -159.78, 'lat': -21.21}
# kushiro
# {'lon': 144.37, 'lat': 42.98}
# grand river south east
# grand river south eastNot Found
# sault sainte marie
# {'lon': -84.33, 'lat': 46.52}
# san andres
# {'lon': -81.7, 'lat': 12.58}
# bur gabo
# bur gaboNot Found
# rach gia
# {'lon': 105.08, 'lat': 10.02}
# olinda
# {'lon': -34.86, 'lat': -8.01}
# praia da vitoria
# {'lon': -27.07, 'lat': 38.73}
# ushtobe
# {'lon': 77.98, 'lat': 45.25}
# surt
# {'lon': 16.59, 'lat': 31.21}
# pangkalanbuun
# {'lon': 111.62, 'lat': -2.68}
# basco
# {'lon': 121.97, 'lat': 20.45}
# sulmona
# {'lon': 13.93, 'lat': 42.05}
# margate
# {'lon': 1.39, 'lat': 51.38}
# ancud
# {'lon': -73.82, 'lat': -41.87}
# east london
# {'lon': 27.91, 'lat': -33.02}
# haines junction
# {'lon': -137.51, 'lat': 60.75}
# souillac
# {'lon': 57.52, 'lat': -20.52}
# caborca
# {'lon': -111.1, 'lat': 30.58}
# zhaocheng
# zhaochengNot Found
# nadym
# {'lon': 72.52, 'lat': 65.53}
# hambantota
# {'lon': 81.12, 'lat': 6.12}
# faanui
# {'lon': -151.75, 'lat': -16.48}
# san juan de los morros
# {'lon': -67.35, 'lat': 9.91}
# jaisalmer
# {'lon': 70.92, 'lat': 26.91}
# bonavista
# {'lon': -53.11, 'lat': 48.65}
# srednekolymsk
# {'lon': 153.68, 'lat': 67.45}
# eganville
# {'lon': -77.1, 'lat': 45.53}
# paracuru
# {'lon': -39.03, 'lat': -3.41}
# cochrane
# {'lon': -114.47, 'lat': 51.18}
# maceio
# {'lon': -35.74, 'lat': -9.67}
# mokhsogollokh
# {'lon': 128.92, 'lat': 61.47}
# maposeni
# {'lon': 35.4, 'lat': -10.58}
# healesville
# {'lon': 145.52, 'lat': -37.65}
# morgan city
# {'lon': -91.21, 'lat': 29.7}
# san cristobal
# {'lon': -72.22, 'lat': 7.77}
# yazykovo
# {'lon': 56.14, 'lat': 55.22}
# severo-kurilsk
# {'lon': 156.12, 'lat': 50.68}
# samusu
# samusuNot Found
# houston
# {'lon': -95.36, 'lat': 29.76}
# esna
# {'lon': 32.55, 'lat': 25.29}
# angra dos reis
# {'lon': -44.32, 'lat': -23.01}
# hat yai
# {'lon': 100.48, 'lat': 7.01}
# missoula
# {'lon': -113.8, 'lat': 47.02}
# tvoroyri
# {'lon': -6.81, 'lat': 61.56}
# kudahuvadhoo
# {'lon': 72.89, 'lat': 2.67}
# balotra
# {'lon': 72.23, 'lat': 25.83}
# tuktoyaktuk
# {'lon': -133.04, 'lat': 69.45}
# klyuchi
# {'lon': 79.17, 'lat': 52.27}
# caravelas
# {'lon': -39.25, 'lat': -17.71}
# nizhniy tsasuchey
# {'lon': 115.13, 'lat': 50.52}
# sandnessjoen
# {'lon': 12.63, 'lat': 66.02}
# havre-saint-pierre
# {'lon': -63.6, 'lat': 50.23}
# tiksi
# {'lon': 128.87, 'lat': 71.69}
# zelenoborsk
# {'lon': 64.03, 'lat': 61.47}
# fallon
# {'lon': -118.78, 'lat': 39.47}
# mercedes
# {'lon': -59.43, 'lat': -34.65}
# dunedin
# {'lon': 170.5, 'lat': -45.87}
# faya
# {'lon': 42.45, 'lat': 18.39}
# barrow
# {'lon': -156.79, 'lat': 71.29}
# luoyang
# {'lon': 112.45, 'lat': 34.68}
# ouargaye
# {'lon': 0.06, 'lat': 11.5}
# aginskoye
# {'lon': 114.53, 'lat': 51.1}
# alpatovo
# {'lon': 45.24, 'lat': 43.7}
# samarai
# {'lon': 150.67, 'lat': -10.62}
# sandwick
# {'lon': -1.25, 'lat': 60}
# kieta
# {'lon': 155.63, 'lat': -6.22}
# samalaeulu
# samalaeuluNot Found
# aksarka
# {'lon': 67.8, 'lat': 66.56}
# labuhan
# {'lon': 112.21, 'lat': -6.88}
# novobelokatay
# {'lon': 58.95, 'lat': 55.71}
# uk
# ukNot Found
# kaitangata
# {'lon': 169.85, 'lat': -46.28}
# urengoy
# {'lon': 78.37, 'lat': 65.97}
# neiafu
# {'lon': -173.98, 'lat': -18.65}
# nyagan
# {'lon': 65.39, 'lat': 62.14}
# cheuskiny
# cheuskinyNot Found
# egvekinot
# {'lon': -179.17, 'lat': 66.32}
# jurado
# {'lon': -77.76, 'lat': 7.11}
# freeport
# {'lon': -73.58, 'lat': 40.66}
# kashan
# {'lon': 51.44, 'lat': 33.98}
# port lincoln
# {'lon': 135.87, 'lat': -34.73}
# cayenne
# {'lon': -52.33, 'lat': 4.93}
# dolores
# {'lon': -57.68, 'lat': -36.31}
# altud
# {'lon': 43.87, 'lat': 43.72}
# cherskiy
# {'lon': 161.3, 'lat': 68.75}
# bikaner
# {'lon': 73.3, 'lat': 28.02}
# calbe
# {'lon': 11.77, 'lat': 51.9}
# coquimbo
# {'lon': -71.34, 'lat': -29.95}
# bud
# {'lon': -86.18, 'lat': 39.45}
# mount gambier
# {'lon': 140.77, 'lat': -37.83}
# tsiroanomandidy
# {'lon': 46.03, 'lat': -18.77}
# jiayuguan
# {'lon': 98.3, 'lat': 39.82}
# sanming
# {'lon': 117.62, 'lat': 26.25}
# plettenberg bay
# {'lon': 23.37, 'lat': -34.05}
# miraflores
# {'lon': -98.81, 'lat': 19.22}
# matamoros
# {'lon': -103.25, 'lat': 25.53}
# praya
# {'lon': -23.51, 'lat': 14.92}
# san julian
# {'lon': -102.17, 'lat': 21.02}
# torrijos
# {'lon': -4.28, 'lat': 39.98}
# tartagal
# {'lon': -63.8, 'lat': -22.52}
# kavaratti
# {'lon': 72.64, 'lat': 10.57}
# esperance
# {'lon': 121.9, 'lat': -33.87}
# tsihombe
# tsihombeNot Found
# chapais
# {'lon': -74.85, 'lat': 49.78}
# hasaki
# {'lon': 140.83, 'lat': 35.73}
# longyearbyen
# {'lon': 15.64, 'lat': 78.22}
# payson
# {'lon': -111.73, 'lat': 40.04}
# tangjiazhuang
# {'lon': 118.45, 'lat': 39.73}
# ossora
# {'lon': 163.07, 'lat': 59.24}
# ndele
# {'lon': 20.65, 'lat': 8.41}
# arraial do cabo
# {'lon': -42.03, 'lat': -22.97}
# codrington
# {'lon': 141.97, 'lat': -38.27}
# grindavik
# {'lon': -22.43, 'lat': 63.84}
# catamarca
# {'lon': -65.79, 'lat': -28.47}
# amderma
# amdermaNot Found
# nagayo
# {'lon': 129.89, 'lat': 32.82}
# el campo
# {'lon': -96.27, 'lat': 29.2}
# muros
# {'lon': -9.06, 'lat': 42.78}
# fairbanks
# {'lon': -147.72, 'lat': 64.84}
# ovalle
# {'lon': -71.2, 'lat': -30.6}
# khani
# {'lon': 42.96, 'lat': 41.96}
# tiarei
# {'lon': -149.33, 'lat': -17.53}
# nizhneyansk
# nizhneyanskNot Found
# mount isa
# {'lon': 139.5, 'lat': -20.73}
# bijie
# {'lon': 105.29, 'lat': 27.31}
# chumikan
# {'lon': 135.31, 'lat': 54.72}
# the pas
# {'lon': -101.25, 'lat': 53.83}
# bowmore
# {'lon': -79.3, 'lat': 34.94}
# lagoa
# {'lon': -27.98, 'lat': 39.05}
# pangody
# {'lon': 74.49, 'lat': 65.85}
# alta gracia
# {'lon': -64.43, 'lat': -31.65}
# chuy
# {'lon': -53.46, 'lat': -33.7}
# isla vista
# {'lon': -119.86, 'lat': 34.41}
# salinopolis
# {'lon': -47.36, 'lat': -0.61}
# saint george
# {'lon': -113.58, 'lat': 37.1}
# la ronge
# {'lon': -105.28, 'lat': 55.1}
# garachine
# {'lon': -78.36, 'lat': 8.06}
# satitoa
# satitoaNot Found
# berlevag
# {'lon': 29.09, 'lat': 70.86}
# namikupa
# {'lon': 39.6, 'lat': -10.83}
# barra patuca
# {'lon': -84.28, 'lat': 15.8}
# nagato
# {'lon': 131.2, 'lat': 34.38}
# galveston
# {'lon': -94.97, 'lat': 29.37}
# mandalgovi
# {'lon': 106.27, 'lat': 45.76}
# akyab
# {'lon': 92.9, 'lat': 20.15}
# kibray
# {'lon': 69.46, 'lat': 41.39}
# naze
# {'lon': 129.48, 'lat': 28.37}
# hamilton
# {'lon': -84.53, 'lat': 39.18}
# bontang
# {'lon': 117.5, 'lat': 0.13}
# lamar
# {'lon': -95.58, 'lat': 33.67}
# contamana
# {'lon': -75.02, 'lat': -7.33}
# yaqui
# {'lon': -110.17, 'lat': 27.37}
# moroni
# {'lon': 43.26, 'lat': -11.7}
# shelburne
# {'lon': -80.2, 'lat': 44.08}
# matameye
# matameyeNot Found
# karlshamn
# {'lon': 14.86, 'lat': 56.17}
# portobelo
# {'lon': -79.65, 'lat': 9.55}
# rio gallegos
# {'lon': -69.22, 'lat': -51.62}
# xining
# {'lon': 101.77, 'lat': 36.62}
# henties bay
# {'lon': 14.28, 'lat': -22.12}
# ust-koksa
# {'lon': 85.61, 'lat': 50.27}
# meulaboh
# {'lon': 96.13, 'lat': 4.14}
# banda aceh
# {'lon': 95.32, 'lat': 5.56}
# mier
# {'lon': -99.15, 'lat': 26.43}
# sao joao da barra
# {'lon': -41.05, 'lat': -21.64}
# vrbove
# {'lon': 17.72, 'lat': 48.62}
# tilichiki
# {'lon': 166.1, 'lat': 60.47}
# hondo
# {'lon': 130.2, 'lat': 32.45}
# chom bung
# chom bungNot Found
# nantucket
# {'lon': -70.1, 'lat': 41.28}
# trinidad
# {'lon': -64.9, 'lat': -14.83}
# myitkyina
# {'lon': 97.4, 'lat': 25.38}
# sioux lookout
# {'lon': -91.92, 'lat': 50.1}
# quelimane
# {'lon': 36.89, 'lat': -17.88}
# san quintin
# {'lon': -115.95, 'lat': 30.48}
# leningradskiy
# {'lon': 178.42, 'lat': 69.38}
# arlit
# {'lon': 7.39, 'lat': 18.74}
# borba
# {'lon': -59.59, 'lat': -4.39}
# vardo
# {'lon': 31.11, 'lat': 70.37}
# mitsamiouli
# {'lon': 43.28, 'lat': -11.38}
# ribeira grande
# {'lon': -28.7, 'lat': 38.52}
# rengo
# {'lon': -70.87, 'lat': -34.42}
# lagos
# {'lon': 3.75, 'lat': 6.58}
# codajas
# {'lon': -62.06, 'lat': -3.84}
# manadhoo
# {'lon': 73.38, 'lat': 5.77}
# husavik
# {'lon': -17.34, 'lat': 66.04}
# nanakuli
# {'lon': -158.15, 'lat': 21.39}
# patnos
# {'lon': 42.86, 'lat': 39.23}
# novoagansk
# {'lon': 76.66, 'lat': 61.94}
# montepuez
# {'lon': 39, 'lat': -13.13}
# vestmannaeyjar
# {'lon': -20.27, 'lat': 63.44}
# rawson
# {'lon': -65.1, 'lat': -43.3}
# ilulissat
# {'lon': -51.1, 'lat': 69.22}
# urlati
# {'lon': 26.23, 'lat': 44.98}
# melfi
# {'lon': 15.65, 'lat': 41}
# evensk
# {'lon': 159.23, 'lat': 61.95}
# ulaanbaatar
# {'lon': 106.88, 'lat': 47.91}
# comodoro rivadavia
# {'lon': -67.5, 'lat': -45.87}
# deleni
# {'lon': 26.88, 'lat': 47.47}
# lindi
# {'lon': 39.72, 'lat': -10}
# yar-sale
# {'lon': 70.83, 'lat': 66.83}
# palana
# {'lon': 159.97, 'lat': 59.12}
# coihaique
# {'lon': -72.07, 'lat': -45.58}
# rutana
# {'lon': 30.1, 'lat': -3.87}
# omboue
# {'lon': 9.26, 'lat': -1.57}
# aberdeen
# {'lon': -2.1, 'lat': 57.14}
# alta floresta
# {'lon': -56.09, 'lat': -9.88}
# loandjili
# {'lon': 11.86, 'lat': -4.76}
# termoli
# {'lon': 14.99, 'lat': 41.99}
# washington
# {'lon': -120.5, 'lat': 47.5}
# nara
# {'lon': 135.8, 'lat': 34.69}
# tocopilla
# {'lon': -70.2, 'lat': -22.09}
# burley
# {'lon': -113.79, 'lat': 42.54}
# adamovka
# {'lon': 59.94, 'lat': 51.52}
# kampene
# {'lon': 26.67, 'lat': -3.6}
# alice springs
# {'lon': 133.88, 'lat': -23.7}
# sibolga
# {'lon': 98.78, 'lat': 1.74}
# sorland
# {'lon': 12.69, 'lat': 67.67}
# karacakoy
# {'lon': 28.38, 'lat': 41.4}
# fort nelson
# {'lon': -122.7, 'lat': 58.81}
# yumen
# {'lon': 97.2, 'lat': 40.28}
# katsuura
# {'lon': 140.3, 'lat': 35.13}
# karakendzha
# karakendzhaNot Found
# vidim
# {'lon': 103.11, 'lat': 56.41}
# roma
# {'lon': -75.46, 'lat': 43.21}
# phalaborwa
# {'lon': 31.14, 'lat': -23.94}
# abiramam
# {'lon': 78.45, 'lat': 9.47}
# vega de alatorre
# {'lon': -96.63, 'lat': 20.03}
# sitrah
# {'lon': 50.62, 'lat': 26.15}
# shimoda
# {'lon': 138.95, 'lat': 34.67}
# lata
# {'lon': -8.33, 'lat': 40.16}
# namibe
# {'lon': 12.15, 'lat': -15.2}
# north bend
# {'lon': -124.22, 'lat': 43.41}
# lewistown
# {'lon': -77.57, 'lat': 40.6}
# pacific grove
# {'lon': -121.92, 'lat': 36.62}
# lodja
# {'lon': 23.43, 'lat': -3.48}
# damietta
# {'lon': 31.81, 'lat': 31.42}
# rayong
# {'lon': 101.43, 'lat': 12.83}
# pevek
# {'lon': 170.31, 'lat': 69.7}
# palabuhanratu
# palabuhanratuNot Found
# touros
# {'lon': -35.46, 'lat': -5.2}
# yabrud
# {'lon': 36.66, 'lat': 33.97}
# yulara
# {'lon': 130.99, 'lat': -25.24}
# abu samrah
# {'lon': 37.18, 'lat': 35.3}
# sao lourenco da serra
# {'lon': -46.94, 'lat': -23.85}
# adre
# {'lon': 22.2, 'lat': 13.47}
# koutiala
# {'lon': -5.46, 'lat': 12.39}
# kizukuri
# {'lon': 140.39, 'lat': 40.81}
# makrana
# {'lon': 74.72, 'lat': 27.05}
# port moresby
# {'lon': 147.18, 'lat': -9.44}
# kimbe
# {'lon': 150.14, 'lat': -5.55}
# kidal
# {'lon': 1.41, 'lat': 18.44}
# balao
# {'lon': -79.82, 'lat': -2.92}
# victoria
# {'lon': 114.16, 'lat': 22.29}
# pouembout
# {'lon': 164.9, 'lat': -21.13}
# brigantine
# {'lon': -74.36, 'lat': 39.41}
# belyy yar
# {'lon': 91.39, 'lat': 53.6}
# padang
# {'lon': 100.35, 'lat': -0.95}
# boda
# {'lon': 17.47, 'lat': 4.32}
# caxias
# {'lon': -9.28, 'lat': 38.7}
# bolungarvik
# bolungarvikNot Found
# deer lake
# {'lon': -57.43, 'lat': 49.17}
# colwyn bay
# {'lon': -3.73, 'lat': 53.29}
# cairns
# {'lon': 145.77, 'lat': -16.92}
# shangrao
# {'lon': 117.97, 'lat': 28.45}
# baykit
# {'lon': 96.37, 'lat': 61.67}
# port shepstone
# {'lon': 30.45, 'lat': -30.74}
# kemijarvi
# {'lon': 27.43, 'lat': 66.71}
# hobyo
# {'lon': 48.53, 'lat': 5.35}
# petropavlovsk-kamchatskiy
# {'lon': 158.65, 'lat': 53.05}
# tasgaon
# {'lon': 74.6, 'lat': 17.03}
# deputatskiy
# {'lon': 139.9, 'lat': 69.3}
# blythe
# {'lon': -114.6, 'lat': 33.61}
# maniitsoq
# {'lon': -52.9, 'lat': 65.42}
# linxia
# {'lon': 103.21, 'lat': 35.6}
# nancha
# {'lon': 129.27, 'lat': 47.13}
# tonkino
# {'lon': 46.46, 'lat': 57.37}
# shaunavon
# {'lon': -108.42, 'lat': 49.65}
# harnosand
# {'lon': 17.94, 'lat': 62.63}
# cap malheureux
# {'lon': 57.61, 'lat': -19.98}
# ostersund
# {'lon': 14.64, 'lat': 63.18}
# mechanicsville
# {'lon': -77.37, 'lat': 37.61}
# daru
# {'lon': 143.21, 'lat': -9.08}
# bajram curri
# {'lon': 20.08, 'lat': 42.36}
# guaimaca
# {'lon': -86.82, 'lat': 14.53}
# surman
# {'lon': 12.57, 'lat': 32.76}
# kasongo
# {'lon': 26.67, 'lat': -4.45}
# charters towers
# {'lon': 146.27, 'lat': -20.1}
# norrtalje
# {'lon': 18.7, 'lat': 59.76}
# sapulpa
# {'lon': -96.11, 'lat': 36}
# puerto el triunfo
# {'lon': -88.55, 'lat': 13.28}
# kyshtovka
# {'lon': 76.63, 'lat': 56.55}
# ewo
# {'lon': 14.82, 'lat': -0.87}
# kangaatsiaq
# {'lon': -53.46, 'lat': 68.31}
# flin flon
# {'lon': -101.86, 'lat': 54.77}
# karkaralinsk
# karkaralinskNot Found
# victor harbor
# {'lon': 138.62, 'lat': -35.57}
# neuquen
# {'lon': -68.06, 'lat': -38.95}
# norilsk
# {'lon': 88.2, 'lat': 69.35}
# perbaungan
# {'lon': 98.96, 'lat': 3.57}
# bronnoysund
# {'lon': 12.2, 'lat': 65.46}
# svetlogorsk
# {'lon': 29.73, 'lat': 52.63}
# winnemucca
# {'lon': -117.74, 'lat': 40.97}
# mandi bahauddin
# {'lon': 73.48, 'lat': 32.58}
# ribeira brava
# {'lon': -17.07, 'lat': 32.65}
# kannad
# {'lon': 75.13, 'lat': 20.27}
# huinan
# {'lon': 126.26, 'lat': 42.62}
# norman wells
# {'lon': -126.83, 'lat': 65.28}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-44ccc4f2b92a> in <module>
#       8
#       9     try:
# ---> 10         response = requests.get(url +city + '&appid='+weather_api_key ).json()
#      11         print(city)
#      12         print(response['coord'])
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
