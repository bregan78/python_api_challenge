# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
import datetime as dt

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
np.random.seed(10)

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
cities_df = pd.DataFrame(cities)    
cities_df.columns =['City']
cities_df["Lat"] =''
cities_df["Lng"] =''
cities_df["Max Temp"] =''
cities_df["Humidity"] =''
cities_df["Cloudiness"] =''
cities_df["Wind Speed"] =''
cities_df["Country"] =''
cities_df["Date"] =''
cities_df
# Out:
# 586
#               City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country  \
# 0     saint-dizier
# 1           albany
# 2         eldorado
# 3         aurillac
# 4             biak
# ..             ...  ..  ..      ...      ...        ...        ...     ...
# 581          yuyao
# 582          manta
# 583       aripuana
# 584  casambalangan
# 585       burkhala
#
#     Date
# 0
# 1
# 2
# 3
# 4
# ..   ...
# 581
# 582
# 583
# 584
# 585
#
# [586 rows x 9 columns]

# %%
#citiestest=["philadelphia", "baltimore", "fakecity", "albany"]

# %%
#url = " http://api.openweathermap.org/data/2.5/weather?q="

#count = 1
#print("Beginning Data Retrieval")
#api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
#for index, row in cities_pd.iterrows()::
    
    
    #try:
        #print("Processing Record " + str(count) + " | " + city) 
        #response = requests.get(url +city + '&appid='+weather_api_key ).json()
        #time.sleep(2)
        #print(response['coord'])
        #lat.append(response['coord']['lat'])
        #lng.append(response["coord"]["lon"])
        #city_name.append(response["name"])
        #cloudiness.append(response["clouds"]["all"])
        #country.append(response["sys"]["country"])
        #date.append(response["dt"])
        #humidity.append(response["main"]["humidity"])
        #max_temp.append(response["main"]["temp_max"])
        #lat.append(response["coord"]["lat"])
        #lng.append(response["coord"]["lon"])
        #wind_speed.append(response["wind"]["speed"])
    #except KeyError:
        #print(city + " Not Found")
    
    
    #count= count + 1
        
#print(lat)
#response = requests.get(url +'blythe' '&appid='+weather_api_key).json()
#city = response.json()
#print(response)
# Out:
# Beginning Data Retrieval
# Processing Record 1 | philadelphia
# Processing Record 2 | baltimore
# Processing Record 3 | fakecity
# fakecity Not Found
# {'cod': '404', 'message': 'city not found'}

# %%
#print(len(citiestest))
#cities_df_test = pd.DataFrame(citiestest)    
#cities_df_test.columns =['City']
#cities_df_test["Lat"] =''
#cities_df_test["Lng"] =''
#cities_df_test["Max Temp"] =''
#cities_df_test["Humidity"] =''
#cities_df_test["Cloudiness"] =''
#cities_df_test["Wind Speed"] =''
#cities_df_test["Country"] =''
#cities_df_test["Date"] =''
#cities_df_test
# Out:
#            City    Lat    Lng Max Temp Humidity Cloudiness Wind Speed Country  \
# 0  philadelphia  39.95 -75.16
# 1     baltimore  39.29 -76.61
# 2      fakecity
# 3        albany   42.6 -73.97
#
#   Date
# 0
# 1
# 2
# 3

# %%
#citiestest=["philadelphia", "baltimore", "fakecity"]

url = " http://api.openweathermap.org/data/2.5/weather?q="

count = 1
print("Beginning Data Retrieval")
#api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
for index, row in cities_df.iterrows():
    
    
    try:
        time.sleep(1.1)
        city = row['City']
        
        print("Processing Record " + str(count) + " | " + city) 
        count= count + 1
        city_info = requests.get(url +city + '&appid='+weather_api_key ).json()
        
        cities_df.loc[index, "Lat"] = city_info['coord']['lat']
        cities_df.loc[index, "Lng"] = city_info['coord']['lon']
        cities_df.loc[index, "Max Temp"] = city_info["main"]["temp_max"]
        cities_df.loc[index, "Humidity"] = city_info["main"]["humidity"]
        cities_df.loc[index, "Cloudiness"] = city_info["clouds"]["all"]
        cities_df.loc[index, "Wind Speed"] = city_info["wind"]["speed"]
        cities_df.loc[index, "Country"] = city_info["sys"]["country"]
        cities_df.loc[index, "Date"] = city_info["dt"]
        

        
    except KeyError:
        print(city + " Not Found")
        
    continue
    
    
    
        
#print(lat)
#response = requests.get(url +'blythe' '&appid='+weather_api_key).json()
#city = response.json()
print(cities_df.head())
# Out:
# Beginning Data Retrieval
# Processing Record 1 | saint-dizier
# Processing Record 2 | albany
# Processing Record 3 | eldorado
# Processing Record 4 | aurillac
# Processing Record 5 | biak
# Processing Record 6 | cape town
# Processing Record 7 | bluff
# Processing Record 8 | balykshi
# Processing Record 9 | mataura
# Processing Record 10 | punta arenas
# Processing Record 11 | turayf
# Processing Record 12 | barentsburg
# barentsburg Not Found
# Processing Record 13 | puerto ayora
# Processing Record 14 | chunskiy
# Processing Record 15 | loikaw
# Processing Record 16 | vila franca do campo
# Processing Record 17 | mahebourg
# Processing Record 18 | bilibino
# Processing Record 19 | yinchuan
# Processing Record 20 | atuona
# Processing Record 21 | farafangana
# Processing Record 22 | kapaa
# Processing Record 23 | xique-xique
# Processing Record 24 | asau
# Processing Record 25 | hirara
# Processing Record 26 | saleaula
# saleaula Not Found
# Processing Record 27 | kingsville
# ...

# %%
cities_df.to_csv("WeatherPy.csv")

# %%
cities_df['Max Temp'].replace('', np.nan, inplace=True)
# Out:
#            City    Lat     Lng  Max Temp Humidity Cloudiness Wind Speed  \
# 0  saint-dizier  48.42    5.08    283.15       71         63        2.6
# 1        albany   42.6  -73.97    293.15       34          0       3.99
# 2      eldorado -23.79  -54.28    310.65       25         31       3.11
# 3      aurillac  44.92    2.45    280.37       93         90        2.1
# 4          biak  -0.91  122.88    298.76       79         99       2.43
#
#   Country        Date
# 0      FR  1602699436
# 1      US  1602699190
# 2      BR  1602699438
# 3      FR  1602699440
# 4      ID  1602699441

# %%
cities_df_dna=cities_df.dropna()

# %%
print(len(cities_df))
print(len(cities_df_dna))
# Out:
# 586
# 544

# %%
cities_df_dna.to_csv("WeatherPy_removed_DidNotFind_Rows.csv")

# %%
df= pd.read_csv("WeatherPy_removed_DidNotFind_Rows.csv")
new_df=pd.DataFrame(df)
new_df
new_df1 =new_df.drop('Unnamed: 0',axis=1)

len(new_df1)
#new_df1 = new_df.reset_index(index)
#new_df1.head()
# Out:
# 544

# %%
# convert max temp Kelvin to Fahrenheit
kelvin = new_df1["Max Temp"]
new_df1["Max Temp"] = 1.8 * (kelvin - 273) + 32
new_df1.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  saint-dizier  48.42    5.08    50.270        71          63        2.60
# 1        albany  42.60  -73.97    68.270        34           0        3.99
# 2      eldorado -23.79  -54.28    99.770        25          31        3.11
# 3      aurillac  44.92    2.45    45.266        93          90        2.10
# 4          biak  -0.91  122.88    78.368        79          99        2.43
#
#   Country        Date
# 0      FR  1602699436
# 1      US  1602699190
# 2      BR  1602699438
# 3      FR  1602699440
# 4      ID  1602699441

# %%
#convert windspeed default from meter/second to MPH
# 2.23694 mph
#mph =(meter/sec) * 2.23694
mph =2.23694
new_df1["Wind Speed"] =new_df1["Wind Speed"]*mph
new_df1.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  saint-dizier  48.42    5.08    50.270        71          63    5.816044
# 1        albany  42.60  -73.97    68.270        34           0    8.925391
# 2      eldorado -23.79  -54.28    99.770        25          31    6.956883
# 3      aurillac  44.92    2.45    45.266        93          90    4.697574
# 4          biak  -0.91  122.88    78.368        79          99    5.435764
#
#   Country        Date
# 0      FR  1602699436
# 1      US  1602699190
# 2      BR  1602699438
# 3      FR  1602699440
# 4      ID  1602699441

# %%
new_df1.dtypes
new_df1['Date'] = pd.to_datetime(new_df1['Date'], unit='s')
new_df1['Date']  = pd.DatetimeIndex(new_df1['Date']).normalize()
new_df1.head()

new_df1['Date'] = new_df1.Date.dt.strftime('%m/%d/%Y')
#new_df1['Date']  = pd.to_datetime(new_df1['Date']).strftime('%m/%d/%Y')
new_df1.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  saint-dizier  48.42    5.08    50.270        71          63    5.816044
# 1        albany  42.60  -73.97    68.270        34           0    8.925391
# 2      eldorado -23.79  -54.28    99.770        25          31    6.956883
# 3      aurillac  44.92    2.45    45.266        93          90    4.697574
# 4          biak  -0.91  122.88    78.368        79          99    5.435764
#
#   Country        Date
# 0      FR  10/14/2020
# 1      US  10/14/2020
# 2      BR  10/14/2020
# 3      FR  10/14/2020
# 4      ID  10/14/2020

# %%
#sets date for title of plots
date=new_df1['Date'][0]
date
# Out:
# '10/14/2020'

# %%
#Temperature (F) vs. Latitude


plt.scatter(new_df1["Lat"], new_df1["Max Temp"]) 

plt.xticks(np.arange(-60, 90, 20))
#plt.xticks(new_df["Lat"])
plt.xlabel('Latitude')
plt.ylabel("Max Temp Fahrenheit")
plt.title("City Temperature (F) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Temperature (F) vs. Latitude.png")
plt.show()

# %%
#Temperature (F) vs. Latitude - shows the relationship of cities ralationshop of Latitide against Max Temp. 
#There is an obvious curve of temp for cities around the equator. 
#Though there is an interesting patern of colder temps in the northern hemisphere.

# %%
#Latitude vs. Humidity Plot
plt.scatter(new_df1["Lat"], new_df1["Humidity"]) 

plt.xticks(np.arange(-60, 90, 20))
#plt.xticks(new_df["Lat"])
plt.xlabel('Latitude')
plt.ylabel("Humidity %")
plt.title("City Latitude vs Humidity " + date)

plt.grid(True)
plt.savefig("png_files/Latitude vs. Humidity Plot.png")
plt.show()

# %%
#Latitude vs. Humidity Plot
#cities latitude vs Humidity doesnt show much relationship besideds 
#a strong cluster of cities in the top northern hemipsher having more humidity.

# %%
#Latitude vs. Cloudiness Plot
plt.scatter(new_df1["Lat"], new_df1["Cloudiness"]) 

plt.xticks(np.arange(-60, 90, 20))
#plt.xticks(new_df["Lat"])
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness " + date)

plt.grid(True)
plt.savefig("png_files/Latitude vs. Cloudiness Plot.png")
plt.show()

# %%
#Latitude vs. Cloudiness Plot- doesnt such muuch relationship (postive or negative, northern vs southern hemishpere)

# %%
#Latitude vs. Wind Speed Plot
plt.scatter(new_df1["Lat"], new_df1["Wind Speed"]) 

plt.xticks(np.arange(-60, 90, 20))
#plt.xticks(new_df["Lat"])
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)") 
plt.title("City Latitude vs. Wind Speed " + date)

plt.grid(True)
plt.savefig("png_files/Latitude vs. Wind Speed Plot.png")
plt.show()

# %%
#Latitude vs. Wind Speed Plot- Also doesnt show any indications of relationship (postive or negative, northern vs southern hemishpere)

# %%
#setting up northern and Southern Latitudes. 

new_df1_northern = new_df1[new_df1["Lat"]>=0]

print(new_df1_northern)

new_df1_southern = new_df1[new_df1["Lat"]<0]
print(new_df1_southern)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     saint-dizier  48.42    5.08    50.270        71          63    5.816044
# 1           albany  42.60  -73.97    68.270        34           0    8.925391
# 3         aurillac  44.92    2.45    45.266        93          90    4.697574
# 7         balykshi  47.07   51.87    52.070        27           1    6.710820
# 10          turayf  31.67   38.66    73.670        43          23    9.171454
# ..             ...    ...     ...       ...       ...         ...         ...
# 537         harnai  30.10   67.94    68.018        23           0    1.990877
# 538      tongchuan  35.08  109.09    51.620        69         100    1.073731
# 539  makakilo city  21.35 -158.09    79.070        69           1    3.355410
# 540          yuyao  30.05  121.15    70.268        68          45    2.236940
# 543  casambalangan  18.38  122.13    80.546        83          89   15.859905
#
#     Country        Date
# ...

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude
#run linear regression on each relationship

nh_lat=new_df1_northern["Lat"]
nh_max_temp=new_df1_northern["Max Temp"]


#fucntion for linear regression
def linreg(x,y, x_cord, y_cord):
    aa_slope, aa_int, aa_r, aa_p, aa_std_err = stats.linregress(
    x, y)
    aa_fit = aa_slope * x + aa_int
    plt.scatter(x,y)
    plt.plot(x,aa_fit,"r--")
    plt.xticks(x)
    
    line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))
    plt.annotate(line_eq,(x_cord,y_cord), fontsize=15,color="red")
    
linreg(nh_lat,nh_max_temp, -10, 40)

plt.xticks(np.arange(-10, 90, 20))

plt.xlabel('Latitude')
plt.ylabel("Max Temp Fahrenheit")
plt.title("Northern Hemisphere - Temperature (F) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Northern Hemisphere - Temperature (F) vs. Latitude.png")
plt.show()
print(f"The correlation coefficient between Northern Hemisphere - Temperature (F) vs Latitude ' is {round(stats.pearsonr(nh_lat,nh_max_temp)[0],2)}")
# Out:
# The correlation coefficient between Northern Hemisphere - Temperature (F) vs Latitude ' is -0.86

# %%
#Southern Hemisphere - Temperature (F) vs. Latitude

sh_lat=new_df1_southern["Lat"]
sh_max_temp=new_df1_southern["Max Temp"]

linreg(sh_lat,sh_max_temp, -30, 40)

plt.xticks(np.arange(-60, 10, 10))
plt.xlabel('Latitude')
plt.ylabel("Max Temp Fahrenheit")
plt.title("Southern Hemisphere - Temperature (F) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Southern Hemisphere - Temperature (F) vs. Latitude.png")
plt.show()
print(f"The correlation coefficient between Southern Hemisphere - Temperature (F) vs Latitude ' is {round(stats.pearsonr(sh_lat,sh_max_temp)[0],2)}")
# Out:
# The correlation coefficient between Southern Hemisphere - Temperature (F) vs Latitude ' is 0.7

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude: has a strong negative corelation. 
#Southern Hemisphere - Temperature (F) vs. Latitude has  strong postive corelation. 
#The above makese sense because the closer you get to the equator the warmer the weather.

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
nh_lat=new_df1_northern["Lat"]
nh_hum=new_df1_northern["Humidity"]

linreg(nh_lat,nh_hum, 50, 40)

plt.xticks(np.arange(0, 100, 10))
plt.xlabel('Latitude')
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Northern Hemisphere - Humidity (%) vs. Latitude.png")
plt.show()
print(f"The correlation coefficient between Northern Hemisphere - Humidity (%) vs. Latitude ' is {round(stats.pearsonr(nh_lat,nh_hum)[0],2)}")
# Out:
# The correlation coefficient between Northern Hemisphere - Humidity (%) vs. Latitude ' is 0.28

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

sh_hum=new_df1_southern["Humidity"]

linreg(sh_lat,sh_hum, -60, 40)

plt.xticks(np.arange(-60, 10, 10))
plt.xlabel('Latitude')
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Southern Hemisphere - Humidity (%) vs. Latitude.png")
plt.show()
print(f"The correlation coefficient between Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression ' is {round(stats.pearsonr(sh_lat,sh_hum)[0],2)}")
# Out:
# The correlation coefficient between Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression ' is 0.19

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude: Weak corelation
#Southern Hemisphere - Humidity (%) vs. Latitude: Weak corelation
#There seems to be only a small corealtion with latitude and Humidity.

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

nh_cloud=new_df1_northern["Cloudiness"]

linreg(nh_lat,nh_cloud, 50, 40)

plt.xticks(np.arange(0, 100, 10))
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Northern Hemisphere_Cloudiness (%) vs. Latitude.png")
plt.show()
print(f"The correlation coefficient between Northern Hemisphere - Cloudiness (%) vs. Latitude ' is {round(stats.pearsonr(nh_lat,nh_cloud)[0],2)}")
# Out:
# The correlation coefficient between Northern Hemisphere - Cloudiness (%) vs. Latitude ' is 0.14

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

sh_cloud=new_df1_southern["Cloudiness"]

linreg(sh_lat,sh_cloud, -60, 40)

plt.xticks(np.arange(-60, 10, 10))
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - - Cloudiness (%) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Southern Hemisphere_Cloudiness (%) vs. Latitude.png")
plt.show()
print(f"The correlation coefficient between Southern Hemisphere -- Cloudiness (%) vs. Latitude Linear Regression ' is {round(stats.pearsonr(sh_lat,sh_cloud)[0],2)}")
# Out:
# The correlation coefficient between Southern Hemisphere -- Cloudiness (%) vs. Latitude Linear Regression ' is 0.25

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude
#Southern Hemisphere - Cloudiness (%) vs. Latitude
#there seems to be a weak corelation between cloudiness and the latitude. Though there seems to be a lot of 0% cloudiness % 
#for 10-15  cities. which might be bad data.

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
nh_wind=new_df1_northern["Wind Speed"]

linreg(nh_lat,nh_wind, 20, 30)

plt.xticks(np.arange(0, 100, 10))
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere -Wind Speed (mph) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Northern Hemisphere_Wind Speed (mph) vs Latitude.png")

plt.show()
print(f"The correlation coefficient between Northern Hemisphere - Wind Speed (mph) vs. Latitude ' is {round(stats.pearsonr(nh_lat,nh_wind)[0],2)}")
# Out:
# The correlation coefficient between Northern Hemisphere - Wind Speed (mph) vs. Latitude ' is 0.16

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

sh_wind=new_df1_southern["Wind Speed"]

linreg(sh_lat,sh_wind, -60, 20)

plt.xticks(np.arange(-60, 10, 10))
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - - Wind Speed (mph) vs. Latitude " + date)

plt.grid(True)
plt.savefig("png_files/Southern_Hemisphere_Wind Speed (mph) vs Latitude.png")
plt.show()
print(f"The correlation coefficient between Southern Hemisphere -- Wind Speed (mph) vs. Latitude Linear Regression ' is {round(stats.pearsonr(sh_lat,sh_wind)[0],2)}")
# Out:
# The correlation coefficient between Southern Hemisphere -- Wind Speed (mph) vs. Latitude Linear Regression ' is -0.15

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
#Southern Hemisphere - Wind Speed (mph) vs. Latitude
# There is a small positive corelation for northern hemisphere and a small negative corelation with the southern hemisphere.
#There doesnt seems to be any outliers with either set.
